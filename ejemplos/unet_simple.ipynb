# %% [markdown]
# <a href="https://colab.research.google.com/github/edwinb-ai/segnet/blob/master/ejemplos/unet_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# Algunos hiperparámetros
epocas = 30
tam_lote = 2

# %%
# %run "/content/drive/My Drive/Colab Notebooks/modelo.py"

# %%
# %run "/content/drive/My Drive/Colab Notebooks/preprocesamiento.py"

# %%
# %run "/content/drive/My Drive/Colab Notebooks/metricas.py"

# %%
# Extraer las imágenes y normalizar
X, y = extraer_datos(
    "/content/drive/My Drive/Colab Notebooks/dataset/train_images/train-volume.tif",
    "/content/drive/My Drive/Colab Notebooks/dataset/train_images/train-labels.tif"
)

# %%
x_patches, y_patches = muchas_imagenes_en_partes(
    X, y, size=(128, 128), num_partes=4
)

# %%
X_train, X_val, y_train, y_val = train_test_split(x_patches, y_patches,
                                                 test_size=0.4,
                                                 random_state=15)

# %%
# Hacer aumento de datos simple
transformaciones = dict(
    # randomly rotate images in the range (deg 0 to 180)
    rotation_range=15.0,
    # randomly shift images horizontally
    width_shift_range=0.05,
    # randomly shift images vertically
    height_shift_range=0.05,
    # set range for random shear
    shear_range=50,
    # set range for random zoom
    zoom_range=0.2,
    fill_mode="constant",
    horizontal_flip=True,
    vertical_flip=False
)

# %%
# Conjunto de entrenamiento
entrenamiento = aumentar_imagenes_mascaras(X_train, y_train,
                                          transformaciones=transformaciones)

# %%
# Crear callbacks
guardar_modelo = ModelCheckpoint("/content/drive/My Drive/Colab Notebooks/unet_simple.h5",
                                 monitor="val_indice_jaccard",
                                 mode="max",
                                 verbose=1,
                                 save_best_only=True,
                                )
reduce_lr = ReduceLROnPlateau(monitor="val_loss",
                              factor=0.1,
                              verbose=1,
                              mode="min",
                              patience=2,
                             )

# %%
# U-net
modelo_unet = unet(input_size=(128, 128, 1))
modelo_unet.compile(
    loss="binary_crossentropy",
    optimizer=SGD(1e-2, momentum=0.9),
    metrics=[indice_jaccard],
)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0828 19:27:27.471009 140445076948864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0828 19:27:27.490032 140445076948864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0828 19:27:27.495389 140445076948864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0828 19:27:27.525743 140445076948864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0828 19:27:27.617675 140445076948864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0828 19:27:27.627826 140445076948864 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0828 19:27:27.698181 140445076948864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# /content/drive/My Drive/Colab Notebooks/modelo.py:57: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input=inputs, output=conv10)
# W0828 19:27:27.928540 140445076948864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0828 19:27:27.936684 140445076948864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0828 19:27:27.944179 140445076948864 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
modelo_unet.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 64) 36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 128)  147584      conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 256)  590080      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 512)  2359808     conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 512)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 512)    0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 1024)   4719616     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 1024)   9438208     conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 1024)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 1024) 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 512)  2097664     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 1024) 0           dropout_1[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 512)  4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 512)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 256)  524544      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 512)  0           conv2d_6[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 128)  131200      up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 256)  0           conv2d_4[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 64) 32832       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 128 0           conv2d_2[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 2)  1154        conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 1)  3           conv2d_23[0][0]
# ==================================================================================================
# Total params: 31,031,685
# Trainable params: 31,031,685
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
historia = modelo_unet.fit_generator(
    entrenamiento,
    epochs=epocas,
    steps_per_epoch=100,
    validation_data=(X_val, y_val),
    verbose=1,
    callbacks=[guardar_modelo, reduce_lr],
)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 32s 319ms/step - loss: 0.5798 - indice_jaccard: 0.4735 - val_loss: 0.5134 - val_indice_jaccard: 0.6024
#
# Epoch 00001: val_indice_jaccard improved from -inf to 0.60241, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 2/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.4340 - indice_jaccard: 0.6023 - val_loss: 0.3977 - val_indice_jaccard: 0.6649
#
# Epoch 00002: val_indice_jaccard improved from 0.60241 to 0.66492, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 3/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.3621 - indice_jaccard: 0.6652 - val_loss: 0.3638 - val_indice_jaccard: 0.7224
#
# Epoch 00003: val_indice_jaccard improved from 0.66492 to 0.72239, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 4/30
# 100/100 [==============================] - 26s 259ms/step - loss: 0.3433 - indice_jaccard: 0.6908 - val_loss: 0.3300 - val_indice_jaccard: 0.7381
#
# Epoch 00004: val_indice_jaccard improved from 0.72239 to 0.73812, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 5/30
# 100/100 [==============================] - 26s 259ms/step - loss: 0.3279 - indice_jaccard: 0.7082 - val_loss: 0.3180 - val_indice_jaccard: 0.7477
#
# Epoch 00005: val_indice_jaccard improved from 0.73812 to 0.74771, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 6/30
# 100/100 [==============================] - 26s 261ms/step - loss: 0.3120 - indice_jaccard: 0.7206 - val_loss: 0.3238 - val_indice_jaccard: 0.7640
#
# Epoch 00006: val_indice_jaccard improved from 0.74771 to 0.76400, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 7/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.3110 - indice_jaccard: 0.7279 - val_loss: 0.2989 - val_indice_jaccard: 0.7834
#
# Epoch 00007: val_indice_jaccard improved from 0.76400 to 0.78337, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 8/30
# 100/100 [==============================] - 26s 261ms/step - loss: 0.2868 - indice_jaccard: 0.7539 - val_loss: 0.2933 - val_indice_jaccard: 0.7666
#
# Epoch 00008: val_indice_jaccard did not improve from 0.78337
# Epoch 9/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2875 - indice_jaccard: 0.7545 - val_loss: 0.2723 - val_indice_jaccard: 0.7888
#
# Epoch 00009: val_indice_jaccard improved from 0.78337 to 0.78875, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 10/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2734 - indice_jaccard: 0.7632 - val_loss: 0.2646 - val_indice_jaccard: 0.8150
#
# Epoch 00010: val_indice_jaccard improved from 0.78875 to 0.81499, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 11/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2674 - indice_jaccard: 0.7685 - val_loss: 0.2564 - val_indice_jaccard: 0.8113
#
# Epoch 00011: val_indice_jaccard did not improve from 0.81499
# Epoch 12/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2620 - indice_jaccard: 0.7734 - val_loss: 0.2526 - val_indice_jaccard: 0.8116
#
# Epoch 00012: val_indice_jaccard did not improve from 0.81499
# Epoch 13/30
# 100/100 [==============================] - 26s 259ms/step - loss: 0.2614 - indice_jaccard: 0.7739 - val_loss: 0.2506 - val_indice_jaccard: 0.8101
#
# Epoch 00013: val_indice_jaccard did not improve from 0.81499
# Epoch 14/30
# 100/100 [==============================] - 26s 259ms/step - loss: 0.2549 - indice_jaccard: 0.7793 - val_loss: 0.2644 - val_indice_jaccard: 0.7775
#
# Epoch 00014: val_indice_jaccard did not improve from 0.81499
# Epoch 15/30
# 100/100 [==============================] - 26s 259ms/step - loss: 0.2583 - indice_jaccard: 0.7768 - val_loss: 0.2533 - val_indice_jaccard: 0.8176
#
# Epoch 00015: val_indice_jaccard improved from 0.81499 to 0.81756, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 16/30
# 100/100 [==============================] - 26s 259ms/step - loss: 0.2501 - indice_jaccard: 0.7794 - val_loss: 0.2424 - val_indice_jaccard: 0.8216
#
# Epoch 00016: val_indice_jaccard improved from 0.81756 to 0.82160, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 17/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2400 - indice_jaccard: 0.7907 - val_loss: 0.2420 - val_indice_jaccard: 0.8231
#
# Epoch 00017: val_indice_jaccard improved from 0.82160 to 0.82313, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 18/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2396 - indice_jaccard: 0.7917 - val_loss: 0.2408 - val_indice_jaccard: 0.8269
#
# Epoch 00018: val_indice_jaccard improved from 0.82313 to 0.82695, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 19/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2384 - indice_jaccard: 0.7902 - val_loss: 0.2401 - val_indice_jaccard: 0.8231
#
# Epoch 00019: val_indice_jaccard did not improve from 0.82695
# Epoch 20/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2357 - indice_jaccard: 0.7947 - val_loss: 0.2403 - val_indice_jaccard: 0.8271
#
# Epoch 00020: val_indice_jaccard improved from 0.82695 to 0.82713, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 21/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2382 - indice_jaccard: 0.7922 - val_loss: 0.2405 - val_indice_jaccard: 0.8217
#
# Epoch 00021: val_indice_jaccard did not improve from 0.82713
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# Epoch 22/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2338 - indice_jaccard: 0.7928 - val_loss: 0.2383 - val_indice_jaccard: 0.8261
#
# Epoch 00022: val_indice_jaccard did not improve from 0.82713
# Epoch 23/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2339 - indice_jaccard: 0.7960 - val_loss: 0.2387 - val_indice_jaccard: 0.8280
#
# Epoch 00023: val_indice_jaccard improved from 0.82713 to 0.82799, saving model to /content/drive/My Drive/Colab Notebooks/unet_simple.h5
# Epoch 24/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2336 - indice_jaccard: 0.7977 - val_loss: 0.2383 - val_indice_jaccard: 0.8272
#
# Epoch 00024: val_indice_jaccard did not improve from 0.82799
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# Epoch 25/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2324 - indice_jaccard: 0.7963 - val_loss: 0.2383 - val_indice_jaccard: 0.8267
#
# Epoch 00025: val_indice_jaccard did not improve from 0.82799
# Epoch 26/30
# 100/100 [==============================] - 26s 261ms/step - loss: 0.2317 - indice_jaccard: 0.7964 - val_loss: 0.2383 - val_indice_jaccard: 0.8269
#
# Epoch 00026: val_indice_jaccard did not improve from 0.82799
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.99999883788405e-07.
# Epoch 27/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2350 - indice_jaccard: 0.7940 - val_loss: 0.2383 - val_indice_jaccard: 0.8268
#
# Epoch 00027: val_indice_jaccard did not improve from 0.82799
# Epoch 28/30
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2368 - indice_jaccard: 0.7919 - val_loss: 0.2383 - val_indice_jaccard: 0.8268
#
# Epoch 00028: val_indice_jaccard did not improve from 0.82799
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 9.99999883788405e-08.
# Epoch 29/30
# 100/100 [==============================] - 26s 261ms/step - loss: 0.2325 - indice_jaccard: 0.7964 - val_loss: 0.2383 - val_indice_jaccard: 0.8268
#
# Epoch 00029: val_indice_jaccard did not improve from 0.82799
# Epoch 30/30
# 100/100 [==============================] - 26s 261ms/step - loss: 0.2342 - indice_jaccard: 0.7962 - val_loss: 0.2383 - val_indice_jaccard: 0.8268
#
# Epoch 00030: val_indice_jaccard did not improve from 0.82799
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 9.999998695775504e-09.

# %%
plt.figure(figsize=(12, 7))
plt.plot(historia.history["indice_jaccard"])
plt.plot(historia.history["val_indice_jaccard"])
plt.title("Precisión del modelo")
plt.ylabel("Índice Jaccard")
plt.xlabel("Época")
plt.legend(["Entrenamiento", "Validación"], loc="upper left")
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(historia.history["loss"])
plt.plot(historia.history["val_loss"])
plt.title("Pérdida del modelo")
plt.ylabel("Pérdida")
plt.xlabel("Época")
plt.legend(["Entrenamiento", "Validación"], loc="upper left")
plt.show()

# %%
X_test = datos_prueba("/content/drive/My Drive/Colab Notebooks/dataset/test_images/test-volume.tif")

# %%
mejor_modelo = unet(input_size=(512, 512, 1))
mejor_modelo.load_weights("/content/drive/My Drive/Colab Notebooks/unet_simple.h5")
resultados = mejor_modelo.predict(X_test, batch_size=tam_lote, verbose=1)
print(resultados.shape)
# Out:
# /content/drive/My Drive/Colab Notebooks/modelo.py:57: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input=inputs, output=conv10)
# 30/30 [==============================] - 17s 552ms/step
# (30, 512, 512, 1)

# %%
from skimage.filters import threshold_otsu

# %%
thresh = threshold_otsu(resultados[1, :, :, 0])
binario = resultados[1, :, :, 0] > thresh

# %%
plt.figure(figsize=(12, 7))
plt.imshow(resultados[1, :, :, 0], cmap="gray")
plt.figure(figsize=(12, 7))
plt.imshow(binario, cmap="gray")
plt.figure(figsize=(10, 6))
io.imshow(X_test[1, :, :, 0])
io.show()
